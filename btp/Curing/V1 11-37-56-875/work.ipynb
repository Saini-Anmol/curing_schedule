# %%
import pandas as pd

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# --- MySQL Connection ---
server = "35.208.174.2"
database = "jkplanning_CTP"
username = "root"
password = "Dev112233"

engine = create_engine(f'mysql+pymysql://{username}:{password}@{server}/{database}')

engine = create_engine(f'mysql+pymysql://{username}:{password}@{server}/{database}')

try:
    with engine.connect() as connection:
        print("Connection successful!")
except Exception as e:
    print(f"Connection failed: {e}")

try:
    with engine.begin() as conn:  
        # 1. TRUNCATE TABLE
        truncate_query = text(f"TRUNCATE TABLE Daily_Running_Moulds_pcr")
        conn.execute(truncate_query)
        print(f"Table `CuringSchedule` truncated successfully.")

        df.to_sql(name="Daily_Running_Moulds_pcr", con=engine, if_exists='append', index=False)
        print("Curing Schedule is Updated !!!")

except Exception as e:
    print(f"Error: {e}")
# Out:
# Connection successful!
# Table `CuringSchedule` truncated successfully.
# Curing Schedule is Updated !!!

# %%
import pandas as pd
df = pd.read_csv("daily running moulds_feb.csv")
